# %% [markdown]
# # Plot Labels not showing for me
# I'm unable to see the lables I add to my plots using xlabel(), ylabel(), and title in another Jupyter notebook so created this as a testing/debugging environment.
#
# Importing the usual suspects and creating some data to plot

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# making plot draw full width of notebook
plt.rcParams["figure.figsize"] = (20,6) 

# making some data to plot
X = np.random.uniform(-2,5,size=1000)
Y = list(map(lambda a: (a-2)**2*(a+1), X))

# %% [markdown]
# The code that wasn't working:
# Notice the equals signs - they cause the methods to get overwrite and therefore not do what is expected/wanted.
#
# *Note* once I corrected the code I had to restart my jupyter kernel to get the methods intialzed correctly again - so I don't recommend actually running the below code.

# %% [markdown]
# ```
# plt.scatter(X,Y)
# plt.title='y = (x-2)**2 * (x+1)'
# plt.ylabel='Y values'
# plt.xlabel='X values'
# plt.show()
# ```

# %%
plt.scatter(X,Y)
plt.title('y = (x-2)**2 * (x+1)')
plt.ylabel('Y values')
plt.xlabel('X values')
plt.show()
